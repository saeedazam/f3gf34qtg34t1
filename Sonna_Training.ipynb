# %% [markdown]
# # 🚀 Sonna-1.1 Training: 4B Model (Llama 3.2 3B Base)
# ### Designed by Grand Guard | Powered by Unsloth
#
# This notebook is optimized for **Kaggle** (T4 x2 or P100) to train **Sonna 1.1**.
#
# **Project Goals:**
# *   **Thinking Box:** Integrated `<thought>` process for reasoning.
# *   **Identity:** Hardcoded "Sonna 1.1 by Grand Guard" personality.
# *   **MCP Support:** Trained for Model Context Protocol tool calling.
# *   **UI Features:** Support for Canvas, Emojis, and Markdown formatting.

# %% [markdown]
# ## 1. Install Dependencies
# We use Unsloth for 2x faster training and 70% less memory usage.

# %%
# %%capture
# !pip install --no-deps xformers trl peft accelerate bitsandbytes
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install huggingface_hub

# %% [markdown]
# ## 2. Verify Data Files
# Ensure all `.jsonl` datasets are present in the current directory.

# %%
# !ls *.jsonl

# %% [markdown]
# ## 3. Run Training
# Executing `train_sonna_4b.py`. This script handles model loading, dataset merging, and the SFT process.

# %%
# !python train_sonna_4b.py

# %% [markdown]
# ## 4. Packaging Results
# We zip the LoRA adapters for easy download. The GGUF export is also available in the `sonna-4b-gguf` folder.

# %%
# !zip -r sonna-4b-lora.zip sonna-4b-lora
print("Training Complete! Download sonna-4b-lora.zip or check sonna-4b-gguf directory.")
